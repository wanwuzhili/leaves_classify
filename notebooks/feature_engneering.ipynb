# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_train = pd.read_csv('../data/raw/train.csv')

# %%
data_train.describe() # num: 18353, label: 176
# Out:
#                image             label
# count          18353             18353
# unique         18353               176
# top     images/0.jpg  maclura_pomifera
# freq               1               353

# %%
image0_path, label0 = data_train.image[0], data_train.label[0]
print(image0_path)
# Out:
# images/0.jpg

# %%
image0 = plt.imread('../data/raw/'+image0_path)
plt.imshow(image0)

# %%
image0.shape #(224, 224, 3)
# Out:
# (224, 224, 3)

# %%
from torchvision import io

# %%
img0 = io.read_image('../data/raw/'+image0_path)
img0.shape
# Out:
# torch.Size([3, 224, 224])

# %%
plt.imshow(img0.permute(1, 2, 0).numpy())

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le = le.fit(data_train.label)

# %%
len(le.classes_)
# Out:
# 176

# %%
le.inverse_transform([0])
# Out:
# array(['abies_concolor'], dtype=object)

# %%
data_train.label = le.transform(data_train.label)
data_train.label.head(5)
# Out:
# 0    78
# 1    78
# 2    78
# 3    78
# 4    78
# Name: label, dtype: int32

# %%
import torch

# %%
x = [torch.randn((3, 2, 2)), torch.randn((3, 2, 2))]
x = torch.stack(x)
x.shape
# Out:
# torch.Size([2, 3, 2, 2])
